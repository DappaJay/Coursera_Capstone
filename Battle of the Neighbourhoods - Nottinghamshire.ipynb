# %% [markdown]
# # Battle of the Neighbourhoods - New Nottinghamshire Nursing Home

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Nottinghamshire is a County in England.  The UK government forsees that in an ageing population there is a need to provide more accommodation for elderly people (insert data from government website). /n
# ### This accommodation needs to be varied, as the needs of the elderly residents changes from the ages of 60 onwards. /n
# ### This project will examine the age demographics of different areas of Nottinghamshire using a Census 2011 datatable especially created for the project, showing all the local postcodes, the total number of residents /n
# ### per postcode, the number of residents in various age brackets from age 60 upwards, and the mean/median age of residents. /n
# ### A dataset showing existing nursing homes by postcode in Nottinghamshire will be obtained.....(insert where from) and this will be combined with the demographic information to try to obtain an area with the highest number /n
# ### of older residents but with the lowest number of existing nursing homes.  Also to be taken into consideration is the median age of residents of the surrounding postcodes as a labour force will be required to provide care /n
# ### to the elderly residents.
